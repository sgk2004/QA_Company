# %%
# This gist contains a direct connection to a local PostgreSQL database
# called "recorem_db" where the username and password parameters are "postgres"

import psycopg2
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from datetime import datetime
import numpy as np
# %matplotlib notebook

# %%
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/recorem_db')
conn = engine.connect()

# %% [markdown]
# # Event Table

# %%
events_db = pd.read_sql('Select * from qa_event', conn)
events_db.head()
# Out:
#    id  companyId            name              description              terms  \
# 0   1          2        Dev Meet     Java and c+ dev meet                abc
# 1   2          2          string                   string             string
# 2   3          2  Test Engg Meet   Manual and Automation            asdfzxcv
# 3   4          3  My THIRD event  creating my THIRD event  terms&condiftions
# 4   5          3  My Fouth event  creating my THIRD event  terms&condiftions
#
#       location     city     state country     zip  ...  streamUrl  status  \
# 0    town hall   jaipur  Rajsthan   India  302005  ...       None      20
# 1       string   string    string  string  string  ...       None      10
# 2  crown plaza    Tihri   Kodrama   india  870064  ...       None      10
# 3     NT Mahal  Chennai        TN   India  605001  ...       None      10
# 4     NT Mahal  Chennai        TN   India  605001  ...       None      10
#
# ...

# %%
events_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 29 columns):
# id                      541 non-null int64
# companyId               541 non-null int64
# name                    541 non-null object
# description             541 non-null object
# terms                   60 non-null object
# location                541 non-null object
# city                    518 non-null object
# state                   518 non-null object
# country                 523 non-null object
# zip                     541 non-null object
# dateTime                541 non-null int64
# userTicketPrice         541 non-null int64
# recruiterTicketPrice    541 non-null int64
# taxName                 129 non-null object
# taxPercentage           129 non-null float64
# taxId                   129 non-null object
# cover                   412 non-null object
# currency                539 non-null object
# eventType               541 non-null int64
# ...

# %% [markdown]
# # Company Table

# %%
company_db = pd.read_sql('Select * from qa_company', conn)
company_db.head()
# Out:
#    id                 website              name  \
# 0   1                 abc.com   Organizer First
# 1   2  http://pataranTech.com           Recorem
# 2   3  https://www.corda.net/    Guerrilla mail
# 3   4  http://pataranTech.com           googgle
# 4   5                    None  Company PokeMail
#
#                                                 logo    brief  \
# 0                                               None     None
# 1  file_618cceebe035987c2f14fece33b0be635a0599b7....     uiui
# 2  file_dd71a43eb34a40479e7e6e4a0d4367d979bd3b4f.png      abc
# 3  file_44ee4e9c2f8996f3e52017d811dbdd3c8d6d6d24....  fgvbhhj
# 4                                               None     None
#
#                          domain           phone      address           city  \
# 0                          None            None         None           None
# 1  Architecture/Interior Design  +91 8299716657  sadar bazar      Edgewater
# ...

# %% [markdown]
# # Domain Table

# %%
domain_db = pd.read_sql('Select * from qa_domain', conn)
domain_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2055 entries, 0 to 2054
# Data columns (total 10 columns):
# id           2055 non-null int64
# name         2055 non-null object
# userId       634 non-null float64
# eventId      1025 non-null float64
# jobId        396 non-null float64
# status       2055 non-null int64
# createdBy    2055 non-null int64
# updatedBy    2055 non-null int64
# createdAt    2055 non-null int64
# updatedAt    2055 non-null int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 160.7+ KB

# %% [markdown]
# # Job table

# %%
job_db = pd.read_sql('Select * from qa_job', conn)
job_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 21 columns):
# id                  252 non-null int64
# companyId           252 non-null int64
# designation         252 non-null object
# salaryTo            252 non-null int64
# salaryFrom          252 non-null int64
# jobBrief            252 non-null object
# location            252 non-null object
# positions           252 non-null int64
# activeStatus        252 non-null int64
# minQualification    250 non-null object
# minExperience       250 non-null float64
# currency            252 non-null object
# status              252 non-null int64
# createdBy           252 non-null int64
# updatedBy           252 non-null int64
# createdAt           252 non-null int64
# updatedAt           252 non-null int64
# meta                222 non-null object
# jobLocationType     252 non-null int64
# jobType             252 non-null object
# jobTypeOld          252 non-null int64
# ...

# %%
job_db.head()
# Out:
#    id  companyId        designation  salaryTo  salaryFrom  \
# 0   1          4             string         0           0
# 1   2          4  Software Engineer     95000       80000
# 2   3          5          Test Engg    280000      225000
# 3   4          5             string         0           0
# 4   5          5             string         0           0
#
#                           jobBrief     location  positions  activeStatus  \
# 0                           string       string          0            20
# 1  We need a SWE who's really good  6 MetroTech          4            10
# 2                       API Tester          abc          2            10
# 3                           string       string          0            10
# 4                           string       string          0            10
#
#     minQualification  ...  currency status  createdBy  updatedBy   createdAt  \
# 0             string  ...    string     10          0          6  1602506411
# ...

# %%
domain_db=splitDataFrameList(domain_db, target_column= 'name',separator='/')

# %%
domain_db=splitDataFrameList(domain_db, target_column= 'name',separator=',')

# %%
len(domain_db['name'].unique())
# Out:
# 88

# %%
domain_db=domain_db.replace(to_replace ="It",
                 value ="IT")
domain_db=domain_db.replace(to_replace ="it",
                 value ="IT")
domain_db=domain_db.replace(to_replace ="Computers - Software",
                 value ="software")
domain_db=domain_db.replace(to_replace ="Software development",
                 value ="software")

# %%
domain_db['name'].unique()
# Out:
# array(['sfg', 'software', 'JSP', 'CD', 'string', 'HRA', 'Animation', 'IT',
#        'construction', 'Coding', 'Consulting', 'Advisory Services',
#        'GLASS', 'Automotive', 'Automobile', 'Ancillaries', 'Iron',
#        'Steel', 'Architecture', 'Interior Design', 'Banking',
#        'Accounting', 'Financial Services', 'Chemicals', 'Petrochemicals',
#        'Engineering & Design', 'Bio Technology & Life Sciences', 'ITES',
#        'BPO', 'Construction & Engineering', 'Simulation',
#        'Electronics Manufacturing', 'Internet', 'E-commerce',
#        'Computers - Hardware & Networking', 'Oil', 'Gas', 'Petroleum',
#        'Pharmaceutical', 'Plastic', 'Rubber', 'Power', 'Energy',
#        'Railways Specialty', 'Infrastructure', 'It and services',
#        'Food & beverages', 'jiuyf', 'Entertainment', 'Media',
#        'Publishing', 'Any', 'Insurance', 'Education', 'KPO', 'Research',
#        'Analytics', 'Industry', 'Recruitment', 'Staffing', 'RPO',
# ...

# %%
domain_dropNAN =  domain_db[domain_db['eventId'].notna()]
domain_dropNAN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1553 entries, 4 to 3376
# Data columns (total 10 columns):
# id           1553 non-null int64
# name         1553 non-null object
# userId       0 non-null float64
# eventId      1553 non-null float64
# jobId        0 non-null float64
# status       1553 non-null int64
# createdBy    1553 non-null int64
# updatedBy    1553 non-null int64
# createdAt    1553 non-null int64
# updatedAt    1553 non-null int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 133.5+ KB

# %%
domain_dropNAN.head()
# Out:
#    id       name  userId  eventId  jobId  status  createdBy  updatedBy  \
# 4   5         CD     NaN      1.0    NaN      10          0          0
# 5   6     string     NaN      2.0    NaN      10          0          0
# 6   7        HRA     NaN      3.0    NaN      10          0          0
# 7   8  Animation     NaN      4.0    NaN      10          0          0
# 8   9  Animation     NaN      5.0    NaN      10          0          0
#
#     createdAt   updatedAt
# 4  1602139795  1602139795
# 5  1602140492  1602140492
# 6  1602147442  1602147442
# 7  1602160464  1602160464
# 8  1602161066  1602161066

# %% [markdown]
# ### Domain column select

# %%
domain_dropNAN= domain_dropNAN.loc[:, ['id', 'name', 'eventId','jobId']]

# %%
domain_dropNAN['jobId']=domain_dropNAN['jobId'].fillna(0)

# %%
domain_dropNAN=domain_dropNAN.rename(columns={'id':'domain_id',
                                           'name':'domain_name',
                                              'eventId':'event_id'
                                          })

# %%
domain_dropNAN.event_id = domain_dropNAN.event_id.astype(int)

# %%
domain_dropNAN.jobId = domain_dropNAN.jobId.astype(int)

# %%
domain_dropNAN.head()
# Out:
#    domain_id domain_name  event_id  jobId
# 4          5          CD         1      0
# 5          6      string         2      0
# 6          7         HRA         3      0
# 7          8   Animation         4      0
# 8          9   Animation         5      0

# %% [markdown]
# ### Function to Split DataFRame

# %%
def splitDataFrameList(df,target_column,separator):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df

# %% [markdown]
# ### Merging Data

# %% [markdown]
# ### Event columns

# %%
event = events_db.loc[:,[ 'id','companyId' ,'name', 'country','datetime','job_id']]
event.head()
# Out:
#    id  companyId            name country  datetime  job_id
# 0   1          2        Dev Meet   India       NaN     NaN
# 1   2          2          string  string       NaN     NaN
# 2   3          2  Test Engg Meet   india       NaN     NaN
# 3   4          3  My THIRD event   India       NaN     NaN
# 4   5          3  My Fouth event   India       NaN     NaN

# %%
event=event.fillna(0)

# %%
event['datetime']= [datetime.fromtimestamp(x) for x in event['datetime']]

# %%
event.job_id = event.job_id.astype(int)

# %%
event=event.rename(columns={'id':'event_id',
                                           'name':'event_name',
                                           'country':'event_location',
                                           'datetime':'event_time'})
event.head()
# Out:
#    event_id  companyId      event_name event_location          event_time  \
# 0         1          2        Dev Meet          India 1969-12-31 18:00:00
# 1         2          2          string         string 1969-12-31 18:00:00
# 2         3          2  Test Engg Meet          india 1969-12-31 18:00:00
# 3         4          3  My THIRD event          India 1969-12-31 18:00:00
# 4         5          3  My Fouth event          India 1969-12-31 18:00:00
#
#    job_id
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ### Company columns

# %%
company = company_db.loc[:,[ 'id','name' ,'domain', 'country']]
company = company.rename(columns = {"id":"companyId", 'name':'company_name','domain':'company_domain','country':'company_location'})
company.head()
# Out:
#    companyId      company_name                company_domain company_location
# 0          1   Organizer First                          None             None
# 1          2           Recorem  Architecture/Interior Design              USA
# 2          3    Guerrilla mail       IT/Computers - Software              USA
# 3          4           googgle  Architecture/Interior Design            India
# 4          5  Company PokeMail                          None             None

# %%
print(event)

print(company)

event_company= pd.merge(event, company, on='companyId', how='left')
print(event_company)
# Out:
#      event_id  companyId                         event_name event_location  \
# 0           1          2                           Dev Meet          India
# 1           2          2                             string         string
# 2           3          2                     Test Engg Meet          india
# 3           4          3                     My THIRD event          India
# 4           5          3                     My Fouth event          India
# ..        ...        ...                                ...            ...
# 536       546        237  Payment Testing With Third Party           India
# 537       547        237                Live Event Payment               0
# 538       548        251               Testing Ticket Price              0
# 539       549        204                  testing Minor fix          India
# 540       550        204                   testing upcoming              0
#
#              event_time  job_id
# 0   1969-12-31 18:00:00       0
# ...

# %%
event_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541 entries, 0 to 540
# Data columns (total 9 columns):
# event_id            541 non-null int64
# companyId           541 non-null int64
# event_name          541 non-null object
# event_location      541 non-null object
# event_time          541 non-null datetime64[ns]
# job_id              541 non-null int32
# company_name        541 non-null object
# company_domain      539 non-null object
# company_location    539 non-null object
# dtypes: datetime64[ns](1), int32(1), int64(2), object(5)
# memory usage: 40.2+ KB

# %% [markdown]
# ### Event & Company merge

# %%
event_company.head()
# Out:
#    event_id  companyId      event_name event_location          event_time  \
# 0         1          2        Dev Meet          India 1969-12-31 18:00:00
# 1         2          2          string         string 1969-12-31 18:00:00
# 2         3          2  Test Engg Meet          india 1969-12-31 18:00:00
# 3         4          3  My THIRD event          India 1969-12-31 18:00:00
# 4         5          3  My Fouth event          India 1969-12-31 18:00:00
#
#    job_id    company_name                company_domain company_location
# 0       0         Recorem  Architecture/Interior Design              USA
# 1       0         Recorem  Architecture/Interior Design              USA
# 2       0         Recorem  Architecture/Interior Design              USA
# 3       0  Guerrilla mail       IT/Computers - Software              USA
# 4       0  Guerrilla mail       IT/Computers - Software              USA

# %%
event_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541 entries, 0 to 540
# Data columns (total 9 columns):
# event_id            541 non-null int64
# companyId           541 non-null int64
# event_name          541 non-null object
# event_location      541 non-null object
# event_time          541 non-null datetime64[ns]
# job_id              541 non-null int32
# company_name        541 non-null object
# company_domain      539 non-null object
# company_location    539 non-null object
# dtypes: datetime64[ns](1), int32(1), int64(2), object(5)
# memory usage: 40.2+ KB

# %%
domain_dropNAN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1553 entries, 4 to 3376
# Data columns (total 4 columns):
# domain_id      1553 non-null int64
# domain_name    1553 non-null object
# event_id       1553 non-null int32
# jobId          1553 non-null int32
# dtypes: int32(2), int64(1), object(1)
# memory usage: 48.5+ KB

# %%
event_company_domain= pd.merge(event_company, domain_dropNAN, on='event_id', how='left')

# %%
event_company_domain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1558 entries, 0 to 1557
# Data columns (total 12 columns):
# event_id            1558 non-null int64
# companyId           1558 non-null int64
# event_name          1558 non-null object
# event_location      1558 non-null object
# event_time          1558 non-null datetime64[ns]
# job_id              1558 non-null int32
# company_name        1558 non-null object
# company_domain      1556 non-null object
# company_location    1556 non-null object
# domain_id           1553 non-null float64
# domain_name         1553 non-null object
# jobId               1553 non-null float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(2), object(6)
# memory usage: 152.1+ KB

# %%
event_company_domain['domain_id']=event_company_domain['domain_id'].fillna(0)

# %%
event_company_domain.domain_id = event_company_domain.domain_id .astype(int)

# %%
event_company_domain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1558 entries, 0 to 1557
# Data columns (total 12 columns):
# event_id            1558 non-null int64
# companyId           1558 non-null int64
# event_name          1558 non-null object
# event_location      1558 non-null object
# event_time          1558 non-null datetime64[ns]
# job_id              1558 non-null int32
# company_name        1558 non-null object
# company_domain      1556 non-null object
# company_location    1556 non-null object
# domain_id           1558 non-null int32
# domain_name         1553 non-null object
# jobId               1553 non-null float64
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(2), object(6)
# memory usage: 146.1+ KB

# %%
event_company_domain.head()
# Out:
#    event_id  companyId      event_name event_location          event_time  \
# 0         1          2        Dev Meet          India 1969-12-31 18:00:00
# 1         2          2          string         string 1969-12-31 18:00:00
# 2         3          2  Test Engg Meet          india 1969-12-31 18:00:00
# 3         4          3  My THIRD event          India 1969-12-31 18:00:00
# 4         5          3  My Fouth event          India 1969-12-31 18:00:00
#
#    job_id    company_name                company_domain company_location  \
# 0       0         Recorem  Architecture/Interior Design              USA
# 1       0         Recorem  Architecture/Interior Design              USA
# 2       0         Recorem  Architecture/Interior Design              USA
# 3       0  Guerrilla mail       IT/Computers - Software              USA
# 4       0  Guerrilla mail       IT/Computers - Software              USA
#
#    domain_id domain_name  jobId
# 0          5          CD    0.0
# ...

# %%
event_company_domain= event_company_domain[['event_id','companyId','domain_id','job_id',
                                            'event_name','event_location','company_name','company_location','domain_name']]
event_company_domain.head()
# Out:
#    event_id  companyId  domain_id  job_id      event_name event_location  \
# 0         1          2          5       0        Dev Meet          India
# 1         2          2          6       0          string         string
# 2         3          2          7       0  Test Engg Meet          india
# 3         4          3          8       0  My THIRD event          India
# 4         5          3          9       0  My Fouth event          India
#
#      company_name company_location domain_name
# 0         Recorem              USA          CD
# 1         Recorem              USA      string
# 2         Recorem              USA         HRA
# 3  Guerrilla mail              USA   Animation
# 4  Guerrilla mail              USA   Animation

# %%
job_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 21 columns):
# id                  252 non-null int64
# companyId           252 non-null int64
# designation         252 non-null object
# salaryTo            252 non-null int64
# salaryFrom          252 non-null int64
# jobBrief            252 non-null object
# location            252 non-null object
# positions           252 non-null int64
# activeStatus        252 non-null int64
# minQualification    250 non-null object
# minExperience       250 non-null float64
# currency            252 non-null object
# status              252 non-null int64
# createdBy           252 non-null int64
# updatedBy           252 non-null int64
# createdAt           252 non-null int64
# updatedAt           252 non-null int64
# meta                222 non-null object
# jobLocationType     252 non-null int64
# jobType             252 non-null object
# jobTypeOld          252 non-null int64
# ...

# %% [markdown]
# ### Job column select

# %%
job_db = job_db.loc[:,[ 'id','designation' ,'minQualification', 'minExperience']]
job_db.head()
# Out:
#    id        designation   minQualification  minExperience
# 0   1             string             string            0.0
# 1   2  Software Engineer  Bachelor's Degree            3.0
# 2   3          Test Engg                 BE            2.0
# 3   4             string             string            0.0
# 4   5             string             string            0.0

# %% [markdown]
# # Job merge to main table

# %%
event_company_domain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1558 entries, 0 to 1557
# Data columns (total 9 columns):
# event_id            1558 non-null int64
# companyId           1558 non-null int64
# domain_id           1558 non-null int32
# job_id              1558 non-null int32
# event_name          1558 non-null object
# event_location      1558 non-null object
# company_name        1558 non-null object
# company_location    1556 non-null object
# domain_name         1553 non-null object
# dtypes: int32(2), int64(2), object(5)
# memory usage: 109.5+ KB

# %%
job_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 4 columns):
# id                  252 non-null int64
# designation         252 non-null object
# minQualification    250 non-null object
# minExperience       250 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.0+ KB

# %%
job_db=job_db.rename(columns={'id':'job_id'})

# %%
event_company_domain_job= pd.merge(event_company_domain, job_db, on='job_id', how='left')
event_company_domain_job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1558 entries, 0 to 1557
# Data columns (total 12 columns):
# event_id            1558 non-null int64
# companyId           1558 non-null int64
# domain_id           1558 non-null int32
# job_id              1558 non-null int32
# event_name          1558 non-null object
# event_location      1558 non-null object
# company_name        1558 non-null object
# company_location    1556 non-null object
# domain_name         1553 non-null object
# designation         0 non-null object
# minQualification    0 non-null object
# minExperience       0 non-null float64
# dtypes: float64(1), int32(2), int64(2), object(7)
# memory usage: 146.1+ KB

# %%
event_company_domain_job=event_company_domain_job.rename(columns={'designation':'job_designation',
                                                                  'minQualification':'job_minQualification',
                                                                 'minExperience':'job_minExperience'})

# %%
event_company_domain_job.head()
# Out:
#    event_id  companyId  domain_id  job_id      event_name event_location  \
# 0         1          2          5       0        Dev Meet          India
# 1         2          2          6       0          string         string
# 2         3          2          7       0  Test Engg Meet          india
# 3         4          3          8       0  My THIRD event          India
# 4         5          3          9       0  My Fouth event          India
#
#      company_name company_location domain_name job_designation  \
# 0         Recorem              USA          CD             NaN
# 1         Recorem              USA      string             NaN
# 2         Recorem              USA         HRA             NaN
# 3  Guerrilla mail              USA   Animation             NaN
# 4  Guerrilla mail              USA   Animation             NaN
#
#   job_minQualification  job_minExperience
# 0                  NaN                NaN
# 1                  NaN                NaN
# ...

# %%
event_company_domain_job.to_csv('event_company_domain_job.csv')
